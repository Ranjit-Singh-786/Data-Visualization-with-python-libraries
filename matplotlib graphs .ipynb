# %% [markdown]
# # welcome to you in matplotlib for data sciences
# <p> inthis notebook we are covering all that chart  of matplotlib ,which will be used in data scieces<br>
#     </p>
#   <ul>
#     <li> plot()</li>
#     <li>subplot()</li>
#     <li>scatter()</li>
#     <li>bar()</li>
#     <li>hist(histype='bar')</li>
#     <li>pie()</li>
#     <li>boxplot()</li>
#     <li>stackplot()<p> it is similar to the plot or lineplot() but with fill the color</p></li>
#
#    </ul>

# %%
print('u can use this method for importing matplot pyplot')
# import matplotlib.pyplot
# import matplotlib.pyplot as plt
from matplotlib import pyplot as plt
from matplotlib import style
import numpy as np
import pandas as pd
import seaborn as sns
# Out:
# u can use this method for importing matplot pyplot

# %%
df=pd.read_csv('battles.csv')
df.head()
# Out:
#                             name  year  battle_number  \
# 0     Battle of the Golden Tooth   298              1
# 1    Battle at the Mummer's Ford   298              2
# 2             Battle of Riverrun   298              3
# 3       Battle of the Green Fork   298              4
# 4  Battle of the Whispering Wood   298              5
#
#               attacker_king             defender_king attacker_1 attacker_2  \
# 0  Joffrey/Tommen Baratheon                Robb Stark  Lannister        NaN
# 1  Joffrey/Tommen Baratheon                Robb Stark  Lannister        NaN
# 2  Joffrey/Tommen Baratheon                Robb Stark  Lannister        NaN
# 3                Robb Stark  Joffrey/Tommen Baratheon      Stark        NaN
# 4                Robb Stark  Joffrey/Tommen Baratheon      Stark      Tully
#
#   attacker_3 attacker_4 defender_1  ... major_death  major_capture  \
# 0        NaN        NaN      Tully  ...         1.0            0.0
# ...

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# you can use this type and also above type of method importing the style
from matplotlib.pyplot import style

# %%
style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
lis=[method_name for method_name in dir(plt.plot)]
lis
#chek for how many function belong from plot
# Out:
# ['__annotations__',
#  '__builtins__',
#  '__call__',
#  '__class__',
#  '__closure__',
#  '__code__',
#  '__defaults__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__get__',
#  '__getattribute__',
#  '__globals__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__kwdefaults__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__name__',
#  '__ne__',
#  '__new__',
#  '__qualname__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__']

# %% [markdown]
# ## plot

# %%
plt.plot([1, 2, 3,8])
# plt.legend(["showline"])

# %%
plt.plot([1, 2, 3,8],'g',linewidth=5,label="showline")
plt.legend()
plt.tight_layout()        #set the layout 
# plt.legend(["showline"]) you can use this type

# %% [markdown]
# ### if you passed single value than this chart represent the value by axis y

# %%
plt.plot([5, 1, 3,20],lw=5,label='single_line',color='r')
plt.legend()

# %%
plt.plot([5, 1, 3,20],lw=5,ls='dotted',label='single_line',color='r')
plt.legend()

# %%
plot1=plt.plot([1,2,3],[4,5,1])           #  ( X , Y )
plt.title("my first plot")
plt.xlabel("X_Axis")
plt.ylabel('Y_Axis')
# plt.show() #here this command is optional 
# without using this command my graph is displaying
# Out:
# Text(0, 0.5, 'Y_Axis')

# %% [markdown]
# ## fontdict parameter used for change the xlabel and ylable or tittle color and  size and font convert
# # text_align by using loc parameter

# %%
style.use('seaborn-dark')
font1 = {'family':'serif','color':'k','size':20}      # first we defined the dictionary
font2 = {'family':'serif','color':'g','size':20}
plot1=plt.plot([1,2,3],[4,3,1],'p:k',ms=10,label='fontsetting')   # and by using fontdict parameter use the property of dictionary
plt.xlabel('x-axis',fontdict=font2)
plt.ylabel("y-axis",fontdict=font1)
plt.title("text-formatting",loc='center',fontdict=font1) # loc=code of location
plt.legend()
print()
print('in this cell we will cover all all that property which are used for text formatting')
# Out:
# in this cell we will cover all all that property which are used for text formatting

# %% [markdown]
# # plot bar is suitable for single columns atribute and a sorted
# maner because it tells a basic progress of value

# %%
y=[2,5,8,6]
style.use('seaborn-white')
plt.plot(sorted(y),linestyle='dashed',linewidth=5)   # u can use here dotted dashed

# %%
x=[2,4,7,5,11,14,18]
plt.plot(x,marker='o',ms=14,mfc='r')

# marker is a point that are represent movement point

# %%
plt.plot(x,'o-k')

# %%
plt.plot(x,lw=4,color='k',marker='*',ms=12,mfc='yellow')
plt.legend(['lineplot'],loc='right')

# %%
x=[2,4,7,5,11,14,18]
plt.plot(x,marker='*',ms=17,mfc="r")     # mec='r' can used for set otline border of marker

# %%
x=[2,4,7,5,11,14,18]
plt.plot(x,marker='D')

# %%
x=[2,4,7,5,11,14,18]
plt.plot(x,marker='v',ms=15,mfc='r')

# %% [markdown]
# ## here instead of line we will printing the point value
# # and (1,4),(5,6),(9,8) it means combinations of both axis

# %% [markdown]
# # "*--k"  ---> marker,linestyle,color

# %%
####   this is for more helpfull

x=[1,1,5,9,9]
y=[1,8,5,8,1]
# 'p:r' is fmt here p is star rectangle defines and : defines dotted line r defines the color
plt.plot(x,y,'*--k',ms=15,mfc='r')  # here p is used for the rectangle shape and r is used for line color

# %% [markdown]
# # -- is used for dashed line and ms parameter is used for marker size difine

# %%
#                             grid tricks use here

x=[1,5,9]
y=[4,6,8]
plt.plot(x,y,'o--k',color='r',ms=15,label='grid_tricks')
plt.legend()
font1={'family':'Serif','color':'k','size':20}
plt.grid(axis='x',color='k',linestyle='--',linewidth=0.5)       #grid online will be show only x axis u can use y axis and both
plt.xlabel("grid tricks and font color",loc='center',fontdict=font1)  # u can use right and left or center
# Out:
# Text(0.5, 0, 'grid tricks and font color')

# %%
#                             grid tricks use here

x=[1,5,9]
y=[4,6,8]
plt.plot(x,y,'o--k',mfc='r',ms=15,label='grid_tricks')
plt.legend()
font1={'family':'Serif','color':'red','size':20}
plt.grid(axis='x',color='k',linestyle=':',linewidth=0.5)       #grid online will be show only x axis u can use y axis and both
plt.xlabel("grid tricks and font color",loc='center',fontdict=font1)  # u can use right and left or center
# Out:
# Text(0.5, 0, 'grid tricks and font color')

# %%
x=[5,8,10]
y=[12,16,6]
x2=[6,9,11]
y2=[6,15,7]

# %% [markdown]
# ## two plot line create simultaneously

# %%
style.use('seaborn-dark')                                        # ..........ms-----> markersize
plt.plot(x,y,marker='*',ms=20,mfc='k',label='first line',lw=3)    ##     lw.......> linewidth
plt.title("two lines on a single chart",size=22)
plt.xlabel("X_AXIS",size=22)
plt.ylabel("Y_AXIS",size=22)
plt.legend()                      # for labels onthe right corners 
plt.grid(True)     #for gridlines  u can draw only single axis gridlines or y axis gridlines
#colors shortcuts keys
#c:- for purple
#g:- for green
#k:- for black

# %% [markdown]
# ### Here i am adding some future like main label,x axis label and y axis labe

# %% [markdown]
# ## and now i am adding another some feature of plot in this graph

# %%
# style module in matplotli
from matplotlib import style           # style func. is used to design our graph and we can add some anothr property of design

# %% [markdown]
# ## these are all styles of style module in matplotlib

# %%
for styles in plt.style.available:
    print(styles)
print()
print('these are all style in styl module we can use separately all these styles but next time')
# Out:
# Solarize_Light2
# _classic_test_patch
# bmh
# classic
# dark_background
# fast
# fivethirtyeight
# ggplot
# grayscale
# seaborn
# seaborn-bright
# seaborn-colorblind
# seaborn-dark
# seaborn-dark-palette
# seaborn-darkgrid
# seaborn-deep
# seaborn-muted
# seaborn-notebook
# seaborn-paper
# seaborn-pastel
# seaborn-poster
# seaborn-talk
# seaborn-ticks
# seaborn-white
# seaborn-whitegrid
# tableau-colorblind10
#
# these are all style in styl module we can use separately all these styles but next time

# %%
style.use('classic')       #we are using plot on this classic

# %%
dir(plt.style) # this is used for how many function available inside the topic
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  'available',
#  'context',
#  'core',
#  'library',
#  'reload_library',
#  'use']

# %% [markdown]
# ## finally prectice here of plot bar

# %%
x=[2,5,4,8,7]
y=[8,7,9,6,4]
plt.plot(x,y,'*:k',ms=20,mfc='r',linewidth=0.5,label='propertricks')
font3={'family':'serif','color':'dodgerblue','size':20}
plt.legend()
plt.xlabel('x_axis',loc='right',fontdict=font3)
plt.ylabel('y_axis',loc='bottom',fontdict=font3)
plt.grid(axis='x',color='r',linestyle=':')
print("if you want to textalign of y_axis u can use bottom top and center")
print("if you want to textalign of x_axis u can use right left and center")
# Out:
# if you want to textalign of y_axis u can use bottom top and center
# if you want to textalign of x_axis u can use right left and center

# %% [markdown]
# # SUBPLOTS
# ## with the help of subplots function you can draw the multiple chart in a single in a single figure

# %% [markdown]
# # subplot(1,2)
# here first parameter difines the row and second is colomn and third parameter is  defines the number of chart

# %%
#first plot 
x=np.array([51,81,90,75,59])
y=np.array([21,13,25,41,31])
plt.subplot(1,2,1)          # 1 row and 2 column and 3rd denotes the plot no
plt.plot(x,y)
plt.title('first chart')
plt.grid(axis='x',color="k")
plt.xlabel('( 1-2-1 )')
# second plot
plt.subplot(1,2,2)
x2=np.array([2,5,4,8,7])
y2=np.array([8,4,5,9,6])
plt.plot(x2,y2)
plt.title('second chart')
plt.xlabel('( 1-2-2 )')
print('here i am draw a 1 row and 2 columns ,next parameter defines whose number of chart')
# Out:
# here i am draw a 1 row and 2 columns ,next parameter defines whose number of chart

# %% [markdown]
# # subplot(2,1)

# %%
#first plot 
x=np.array([51,81,90,75,59])
y=np.array([21,13,25,41,31])
plt.subplot(2,1,1)      # row , column , chart no.
plt.plot(x,y)
plt.title('first chart')
plt.grid(axis='x',color="k")
plt.ylabel('( 1-2-1 )')
# second plot

plt.subplot(2,1,2)
x2=np.array([2,5,4,8,7])
y2=np.array([8,4,5,9,6])
plt.plot(x2,y2)
plt.title('second chart')
plt.xlabel('( 1-2-2 )')
# Out:
# Text(0.5, 0, '( 1-2-2 )')

# %% [markdown]
# # subplot(2,3)

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 1)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 2)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 3)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 4)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 5)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 6)
plt.plot(x,y)

# %% [markdown]
# #          SCATTER PLOT
# ## alpha is used for opacity of the point ,range of alpha 0 to 1
#  you can use here alpha parameter and not too.
#  you can not see difference there without using alpha
#  by default point color is blue but u can use color parameter here
# # whenever we wil use the scatter , while we have two numerical columns and we want to merge the result with axis x,and axis y
# ## a single point represent a two columns value with the help of x axis and y axis

# %%
# you can use alpha ,s,c,marker,label all parameters

plt.scatter(x2,y2,color='r',marker='*',alpha=0.9,label='show label')   #alpha is opacity of the point value
plt.legend()
plt.xlabel('x_axis',color='r',size=14,family='serif')
plt.ylabel('y-axis')
plt.title('scatter plot')
# plt.grid(axis='x',color='k')
print('x and y value',x2,y2)
# Out:
# x and y value [6, 9, 11] [6, 15, 7]

# %%
plt.subplot(3,1,1)
plt.scatter(x2,y2,color='r',marker='*',alpha=0.9,label='show label')   #alpha is opacity of the point value
plt.legend()
plt.xlabel('x_axis')
plt.ylabel('y-axis')
plt.title('scatter plot')
plt.show()
# plt.grid(axis='x',color='k')



plt.subplot(3,1,2)
plt.scatter(x2,y2,color='r',marker='*',alpha=0.9,label='show label')   #alpha is opacity of the point value
plt.legend()
plt.xlabel('x_axis')
plt.ylabel('y-axis')
plt.title('scatter plot')
plt.show()
# plt.grid(axis='x',color='k')



plt.subplot(3,1,3)
plt.scatter(x2,y2,color='r',marker='*',alpha=0.9,label='show label')   #alpha is opacity of the point value
plt.legend()
plt.xlabel('x_axis')
plt.ylabel('y-axis')
plt.title('scatter plot')
plt.show()
# plt.grid(axis='x',color='k')

# %% [markdown]
# ## multiple scatter plot in a single figure or two points represents two another representation

# %%
import numpy as np
#day one, the age and speed of 13 cars:
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y,label='Radhey',marker='*',color='k')
plt.legend()
plt.title('two chart in a single chart')

#day two, the age and speed of 15 cars:
x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y,label='Ranjit',color='hotpink')
plt.legend()
fontstyle={'family':'serif','color':'r','size':20}
plt.xlabel('x_axis',fontdict=fontstyle)
plt.ylabel('y_axis')
# Out:
# Text(0, 0.5, 'y_axis')

# %% [markdown]
# ## color for each dot in scatter plot

# %% [markdown]
# # cmap parameter c for color and s is used for size and we will assign the different color with the help of number and cmap =viridis

# %%
x=[2,5,4,8]
y=[9,4,8,7]
colo=[0,10,20,30]
siz=[200,50,40,80]
plt.scatter(x,y,c=colo,s=siz,alpha=0.7,cmap=plt.cm.coolwarm)    # shortcut for colormap
plt.colorbar()
plt.show()

# %% [markdown]
# ## last chart of scatter plot
# in this chart we are using random module of numpy for the color and <br> <hr>
# size and inthis chart we will use color,size,cmap,alpha
# <ol>
#     <li>color</li>
#     <li>size</li>
#     <li>cmap</li>
#     <li>alpha</li>
#     </ol>

# %%
colors = np.random.randint(100, size=(100))
colors
# Out:
# array([53, 12, 56, 85,  2, 85, 75,  0, 28, 52, 86, 66, 91, 96, 75, 13, 79,
#        57, 38, 57, 39, 58, 60, 91, 80, 93, 53, 73, 56, 80, 24, 52, 94, 59,
#        91, 12, 22,  8, 70,  1,  7, 67, 40,  9, 98, 41, 70, 90, 73,  2, 96,
#         9, 60, 51, 58, 39, 27, 19, 31,  9, 41,  3, 16, 83,  9, 40, 65, 86,
#        11, 65, 66,  1, 76, 39,  7, 26,  5, 37, 99, 58, 77, 24, 64, 66,  1,
#         2, 58, 78, 73, 53, 38, 67, 34, 19, 48,  2, 40, 13, 99, 94])

# %%
plt.figure(figsize=(12,8))
x = np.random.randint(100, size=(200))
y = np.random.randint(100, size=(200))
colors = np.random.randint(100, size=(200))
sizes = 10 * np.random.randint(100, size=(200))

plt.scatter(x, y, c=colors, s=sizes, alpha=0.5, cmap='nipy_spectral')          # for cmap=plt.cm.coolwarn

plt.colorbar()     # for show the color bar at right side
plt.title("diff color,size,alpha,Colorbar",fontsize=15,color='r',family='serif')  #this is awesome idea 


# lenght of x , y, color , sizes must be equal
# Out:
# Text(0.5, 1.0, 'diff color,size,alpha,Colorbar')

# %%
plt.figure(figsize=(12,8))
x = np.random.randint(100, size=(200))
y = np.random.randint(100, size=(200))
colors = np.random.randint(100, size=(200))
sizes = 10 * np.random.randint(100, size=(200))

plt.scatter(x, y, c=colors,marker='*', s=sizes, alpha=0.5, cmap='nipy_spectral')          # for cmap=plt.cm.coolwarn

plt.colorbar()     # for show the color bar at right side
plt.title("diff color,size,alpha,Colorbar",fontsize=15,color='r',family='serif')  #this is awesome idea 


# lenght of x , y, color , sizes must be equal
# Out:
# Text(0.5, 1.0, 'diff color,size,alpha,Colorbar')

# %% [markdown]
# # bar plot
# when we will use the bar plot whenever we want to see whose chategoery fastes grow ,<br>
# and for checkout where is the highest value<br>
# you can use here,<b> x columns</b> --> categorical columns<br>
# and<b> y axis</b> --> numerical columns

# %%
plt.bar([1,3,5,7,8],[5,8,7,4,8],color='y',edgecolor='k',lw=3)   # u can use ec instead of edgecolor
# if you want to change the color then you should remember that not use only 'c' here it is mandatory full keyword use 'color'
#here must be equal both list size  
# and here u con,t single axis 
# [x_axis,y_axis]
plt.title('bar plot')



#  ec=== edgecolor   for outer line
#  fc=== face color  for bar color
#  lw=== linewidth   for difine the size of outer line
# Out:
# Text(0.5, 1.0, 'bar plot')

# %%
plt.bar([1,3,5,7,8],[5,8,7,4,8],color='b',ec='k',fc='g',lw=2) 
plt.show()

# %% [markdown]
# ## here i am using same name mohan two times
# and you can see now where mohan has greatest value than bar will be increase like that

# %%
# in this bar chart i am using almost every property
plt.figure(figsize=(12,8))
style.use("seaborn-dark")   # in this style all dotted line gone to behind the bars
col=['black','blue','green','hotpink']

plt.bar(["mohan",'raju','mohan','kiran','shyam'],[5,2,7,8,2],label='customers',edgecolor='k',lw=2,color=col)
plt.ylabel("profit",fontsize=15,color='b')
plt.xlabel("customeres",fontsize=15,color='b')

plt.title("Bar plot",fontsize=25,color='k')
plt.grid(axis='y',color='k',linestyle='dotted',linewidth=2,alpha=0.7)
plt.legend()        

#without using legend function u can,t display the

# %% [markdown]
# ## two bar create simultaneously

# %%
plt.figure(figsize=(12,8))

style.use('seaborn-white')
plt.bar([1,3,5,7,9],[5,2,7,8,2],label='first bar',color='k',edgecolor='g',lw=5)
plt.bar([8,4,6],[5,9,2],label='second bar',color='g',edgecolor='red',lw=5)
#here if you passed same xaxis any for the both bar
# you should keep remeber that it is not possible
# t
plt.legend()

# %% [markdown]
# ## bar plot is representation of catogorical data

# %%
# here i am creating bar plot for database

style.use('seaborn-white')
x=["maharashtra",'tamilnade','chenni','lucknow',]
y=[825,555,342,223]
col=['orange','green','red','hotpink']
plt.bar(x,y,label='database bar plot',color=col)
plt.legend()
plt.title("data base chart")
plt.ylabel("cases",fontsize=15)
plt.xlabel("area",fontsize=15)
plt.grid(axis='y',linewidth=2,color='k')

# %% [markdown]
# <h1>Histogram</h1>
# # histogram for the datadistribution
# this is one of best chart according to me for the data distribution ,<br>
# here we will create a bins in this we will the list according to my bar will be create
# and with filling the our density range
# <b> and always remeber bins is axis x value</b>
# but <b>sytex assigning some deffirent (x,y) instead of (population,bins)</b>

# %%
np.random.randint(50,size=(50))   #for randomly int number generate
# Out:
# array([37, 13, 41, 12, 18, 22, 40,  8, 12, 20, 13, 27,  6,  5,  5,  2, 42,
#        14, 34, 31, 23, 40, 37, 39, 29, 39, 26, 20, 21, 43, 20, 49, 48, 15,
#        41, 18, 44, 30, 43, 33, 35, 13,  9, 25, 36, 11, 11, 38, 30, 33])

# %%
# and bins size aways in ascending sorted maner
plt.figure(figsize=(12,8))

style.use('seaborn-dark')
bins=[0,20,40,60,80,100]       #bins size is 11 but here only 10 bar will be created
population_ages=[22,55,62,54,85,45,25,14,65,74,54,65,25,1,2,10,25,45,85,47,56,95,5,69,36,46,52,74,76,48,49,85,59,51,52,48,75,69,57,58,97,98,32,25,18,17,19,21,22,23,24,26,21,35,34]
plt.hist(population_ages,bins,histtype='bar',color='r',rwidth=0.5,edgecolor='k',lw=4)
plt.xlabel('population record',size=14)
plt.ylabel('the value of population according to my bins',size=14)
plt.title('histogram',color='k',size=14)
plt.grid(axis='y',color='b',alpha=0.9,ls='dashed')

# %%
data=np.random.randint(400,size=(400))
bins=[0,50,100,200,300,400]
plt.hist(data,bins,ec='k',lw=2,rwidth=0.4)
# Out:
# (array([ 55.,  51.,  95., 112.,  87.]),
#  array([  0,  50, 100, 200, 300, 400]),
#  <BarContainer object of 5 artists>)

# %%
data=np.random.randint(100,size=(100))
bins=[0,20,40,60,80]
plt.hist(data,bins,ec='k',lw=2,rwidth=0.4)
# Out:
# (array([23., 18., 15., 23.]),
#  array([ 0, 20, 40, 60, 80]),
#  <BarContainer object of 4 artists>)

# %%
np.random.normal(2,3,size=(5,2))
#prectise for another something
# Out:
# array([[ 1.31467347,  3.21435748],
#        [-0.95462743,  4.45060776],
#        [ 0.22896233, -0.52212263],
#        [-1.42472564,  3.11424112],
#        [-0.57629766, -0.25906671]])

# %%
plt.figure(figsize=(12,8))

bins=[0,17,25,35,50,70,100]  #binsize always incremental
population_ages=[22,55,62,54,85,45,25,14,65,74,54,65,25,1,2,10,25,45,85,47,56,95,5,69,36,46,52,74,76,48,49,85,59,51,52,48,75,69,57,58,97,98,32,25,18,17,19,21,22,23,24,26,21,35,34]
plt.hist(population_ages,bins,histtype='bar',align='mid',orientation='vertical',color='blue',ec='k',lw=2,rwidth=0.4)
plt.xlabel('x axis',fontsize=15)
plt.ylabel('y axis')
plt.title('histogram')
plt.show()

# %% [markdown]
# ## histogram for horizontal

# %%
plt.figure(figsize=(12,8))

bins=[0,17,25,35,50,70,100]  #binsize always incremental
population_ages=[22,55,62,54,85,45,25,14,65,74,54,65,25,1,2,10,25,45,85,47,56,95,5,69,36,46,52,74,76,48,49,85,59,51,52,48,75,69,57,58,97,98,32,25,18,17,19,21,22,23,24,26,21,35,34]
plt.hist(population_ages,bins,histtype='bar',align='mid',orientation='horizontal',color='blue',label=['histogram'],rwidth=0.6,fc='skyblue',edgecolor='k' ,lw=4)
plt.xlabel('x axis',fontsize=15)
plt.ylabel('y axis')
plt.legend()
plt.title('histogram')
# Out:
# Text(0.5, 1.0, 'histogram')

# %% [markdown]
# ## here i was used the python for some additional help

# %%
new_list=[]
for i in population_ages:
    
    if i>60 and i<80:
        new_list.append(i)
print(new_list)
# Out:
# [62, 65, 74, 65, 69, 74, 76, 75, 69]

# %%
list_of_elemnt_whichare_abovesixteen=[i for i in population_ages if i>60 and i<80]
print(min(list_of_elemnt_whichare_abovesixteen))
print(len(list_of_elemnt_whichare_abovesixteen))
print(max(list_of_elemnt_whichare_abovesixteen))
print(sum(list_of_elemnt_whichare_abovesixteen))
list_of_elemnt_whichare_abovesixteen
# Out:
# 62
# 9
# 76
# 629
# [62, 65, 74, 65, 69, 74, 76, 75, 69]

# %% [markdown]
# ## Histogram
# you can use <b> plt.hist </b> for the full syntex inquiry

# %%
plt.pie
# Out:
# <function matplotlib.pyplot.pie(x, explode=None, labels=None, colors=None, autopct=None, pctdistance=0.6, shadow=False, labeldistance=1.1, startangle=0, radius=1, counterclock=True, wedgeprops=None, textprops=None, center=(0, 0), frame=False, rotatelabels=False, *, normalize=None, data=None)>

# %%
plt.plot
# Out:
# <function matplotlib.pyplot.plot(*args, scalex=True, scaley=True, data=None, **kwargs)>

# %%
plt.bar
# Out:
# <function matplotlib.pyplot.bar(x, height, width=0.8, bottom=None, *, align='center', data=None, **kwargs)>

# %%
plt.scatter
# Out:
# <function matplotlib.pyplot.scatter(x, y, s=None, c=None, marker=None, cmap=None, norm=None, vmin=None, vmax=None, alpha=None, linewidths=None, verts=<deprecated parameter>, edgecolors=None, *, plotnonfinite=False, data=None, **kwargs)>

# %%
plt.hist          #this sytex is helpful for know about the syntex
# Out:
# <function matplotlib.pyplot.hist(x, bins=None, range=None, density=False, weights=None, cumulative=False, bottom=None, histtype='bar', align='mid', orientation='vertical', rwidth=None, log=False, color=None, label=None, stacked=False, *, data=None, **kwargs)>

# %%
plt.figure(figsize=(12,8))

population_ages=[22,55,62,54,85,45,25,14,65,74,54,65,25,1,2,10,25,45,85,47,56,95,5,69,36,46,52,74,76,48,49,85,59,51,52,48,75,69,57,58,97,98,32,25,18,17,19,21,22,23,24,26,21,35,34]
categoery=[0,20,40,60,80,100,120]
plt.hist(population_ages,categoery,ec='k',lw=2,color='orange',histtype='bar',label='chart',rwidth=0.8)
plt.title('histogram')
plt.ylabel('population_ages')
plt.xlabel('catigory wise segmentation')
plt.legend()
# plt.grid(True,color='k')   #for gridline

# %%
help(np.random.normal)  # for the help other recomondation

# %%
print(np.random.normal.__doc__)
# Out:
#         normal(loc=0.0, scale=1.0, size=None)
#
#         Draw random samples from a normal (Gaussian) distribution.
#
#         The probability density function of the normal distribution, first
#         derived by De Moivre and 200 years later by both Gauss and Laplace
#         independently [2]_, is often called the bell curve because of
#         its characteristic shape (see the example below).
#
#         The normal distributions occurs often in nature.  For example, it
#         describes the commonly occurring distribution of samples influenced
#         by a large number of tiny, random disturbances, each with its own
#         unique distribution [2]_.
#
#         .. note::
#             New code should use the ``normal`` method of a ``default_rng()``
#             instance instead; please see the :ref:`random-quick-start`.
#
#         Parameters
#         ----------
#         loc : float or array_like of floats
#             Mean ("centre") of the distribution.
# ...

# %% [markdown]
# # Pie chart
# <p> we will learn in this section pie chart. pie is used for catogorical data representation<br>
#     as percentage value</p>

# %%
print(plt.pie.__doc__)  #you can read full documentation of pie chart and how many parameter will be used in pie chart
# Out:
# Plot a pie chart.
#
# Make a pie chart of array *x*.  The fractional area of each wedge is
# given by ``x/sum(x)``.  If ``sum(x) < 1``, then the values of *x* give
# the fractional area directly and the array will not be normalized. The
# resulting pie will have an empty wedge of size ``1 - sum(x)``.
#
# The wedges are plotted counterclockwise, by default starting from the
# x-axis.
#
# Parameters
# ----------
# x : 1D array-like
#     The wedge sizes.
#
# explode : array-like, default: None
#     If not *None*, is a ``len(x)`` array which specifies the fraction
#     of the radius with which to offset each wedge.
#
# labels : list, default: None
#     A sequence of strings providing the labels for each wedge
#
# colors : array-like, default: None
#     A sequence of colors through which the pie chart will cycle.  If
#     *None*, will use the colors in the currently active cycle.
#
# autopct : None or str or callable, default: None
# ...

# %%
plt.pie
# Out:
# <function matplotlib.pyplot.pie(x, explode=None, labels=None, colors=None, autopct=None, pctdistance=0.6, shadow=False, labeldistance=1.1, startangle=0, radius=1, counterclock=True, wedgeprops=None, textprops=None, center=(0, 0), frame=False, rotatelabels=False, *, normalize=None, data=None)>

# %%
# ,,,,,,,,,,labels,,,,,,,,,,,,,,,,,,

plt.figure(figsize=(12,8))

slices=[412,215,367,521,254]
labell=['python','java','java script','c','c++']
plt.pie(slices,labels=labell,autopct="%1.2f%%")
plt.show()

# %%
# ,,,,,,,,shadow=True,,,,,,,,,,
plt.figure(figsize=(12,8))

slices=[412,215,367,521,254]
labell=['python','java','java script','c','c++']

plt.pie(slices,labels=labell,shadow=True,autopct="%1.2f%%")
plt.show()

# %% [markdown]
# # wedgeprops
# <p> is used for the slices property</p>

# %%
# ,,,,,,,,,,,,,wedgeprops----->edgecolor=black
plt.figure(figsize=(12,7))
slices=[412,215,367,521,254]
labell=['python','java','java script','c','c++']

plt.pie(slices,labels=labell,shadow=True,wedgeprops={'edgecolor':'black','linewidth':2,'linestyle':'-'},autopct="%1.2f")
plt.show()

# %% [markdown]
# #   startangle
# <p> is used for start the representation of slices</p>
# <br>
# <p>in this parameter we have only 4 startangle and there are</p><br>
# <ul>
#     <li>0   degree angle</li>
#     <li>90  degree angle</li>
#     <li>180 degree angel</li>
#     <li>270 degree agel</li>
#     </ul>

# %%
# ,,,,,,,,,,startagnle=90,,,,,,,,0,180,90,270 there are four startangle
plt.figure(figsize=(12,7))

slices=[412,215,367,521,254]
labell=['python','java','java script','c','c++']

plt.pie(slices,labels=labell,wedgeprops={'ec':'k'},startangle=90)

# you can not define the ec outside the wedgeprops
plt.show()

# %% [markdown]
# # autopct
# <p> is used for show the percentage value for each slices</p>
# paramater is <b>"%1.1f%%"</b>
# <p> here you can use 1integer value and 2f it means how many floating number you want to see</p>

# %%
# ,,,,,,,,,,,,autopct,,,,,,,,,,,,
plt.figure(figsize=(10,7))
slices=[412,215,367,521,254]
labell=['python','java','java script','c','c++']

plt.pie(slices,labels=labell,wedgeprops={'edgecolor':'black'},shadow=True,startangle=0,autopct="%1.1f%%")
plt.show()

# %% [markdown]
# ## explode property,
# <p> is used for assign the space in between pie chart slices</p>

# %%
# int(10/100*100)   # percentage formula=======10
# 10/500*100-------2
10*100/500---------2
1000*3/100---------30   # PERCENTAGE RATE WITH INTEREST
PRICE.MEAN()/100          # ANOTHER TRICK FOR FINDOUT PERCENTAGE
50000*3/100*12 ------18000  # FOR ONE YEAR
    P/FP*100
    P*100/FP
    P*R/100  --------# FOR  RATE PERCENTAGE
# Out:
# 2.0

# %%
1000*3/100*4  # for 4 month
# Out:
# 120.0

# %%
10000*3/100*4   I TOOK TEN THOUSAND RUPE. ON 3 PERC.. RATE
# Out:
# 1200.0

# %%
5000*5/100*4      I GIVEN 5000 RUPEES ON 5 PERCENTAGE RATE
# Out:
# 1000.0

# %%
1200-1000           AFTER 4 MONTH I WILL HAVE TO PAY ONLY 200 RUPEES 
# ALAG SE DENE PADENGE
# Out:
# 200

# %%
plt.figure(figsize =(10, 7))
slices=[412,215,367,521,254]
labell=['python','java','java script','c','c++']      # last value of c++ will start by the startangle
explod=[0,0.1,0,0.1,0.2]
plt.pie(slices,labels=labell,shadow=True,wedgeprops={'edgecolor':'k','lw':'3'},explode=explod,startangle=90,autopct='%1.2f%%')
plt.show()

# %% [markdown]
# # define the figure size with the help of figure function from the matplotlib
# <h2><b>plt.figure(figsize=(10,7))</b></h2>

# %%
plt.figure(figsize =(8, 7))
slices=[412,215,367,521,254]
labell=['python','java','java script','c','c++']
explod=[0,0,0,0,0.2]
plt.pie(slices,labels=labell,shadow=True,wedgeprops={'edgecolor':'white'},explode=explod,startangle=90,autopct='%1.2f%%')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# # code of this chart access from the greatlearning
# <P> i extracted this coaded for the know more about of pie chart...</P>

# %%
# Creating dataset
cars = ['AUDI', 'BMW', 'FORD', 
        'TESLA', 'JAGUAR', 'MERCEDES']
  
data = [23, 17, 35, 29, 12, 41]
  
  
# Creating explode data
explode = (0.1, 0.0, 0.2, 0.3, 0.0, 0.0)
  
# Creating color parameters
colors = ( "orange", "cyan", "brown",
          "grey", "indigo", "beige")
  
# Wedge properties
wp = { 'linewidth' : 1, 'edgecolor' : "green" }
  
# Creating autocpt arguments
def func(pct, allvalues):
    absolute = int(pct / 100.*np.sum(allvalues))
    return "{:.1f}%\n({:d} g)".format(pct, absolute)
  
# Creating plot
fig, ax = plt.subplots(figsize =(10, 7))
wedges, texts, autotexts = ax.pie(data, 
                                  autopct = lambda pct: func(pct, data),      #awesome trick lambda with in function
                                  explode = explode, 
                                  labels = cars,
                                  shadow = True,
                                  colors = colors,
                                  startangle = 90,
                                  wedgeprops = wp,
                                  textprops = dict(color ="magenta"))
  
# Adding legend
ax.legend(wedges, cars,
          title ="Cars",
          loc ="center left",
          bbox_to_anchor =(1, 0, 0.5, 1))
  
plt.setp(autotexts, size = 8, weight ="bold")
ax.set_title("Customizing pie chart")
plt.show()    # if you are using show()then you can watch only chart no other any text

# %%
##,,,,,,,,another tricks for python,,,,,,,,,,,,,
textprops = dict(color="magenta")
print(type(textprops))
textprops
# Out:
# <class 'dict'>
# {'color': 'magenta'}

# %% [markdown]
# # pie chart with in a pie chart
# <p> in this pie chart i drawed a multiple pie chart<br>
#     with in a pie chart..</p>

# %%
plt.figure(figsize=(9,6))
col=['r'if i%2==0 else 'w' for i in range(1,21)]
col2=['w'if i%2==0 else 'b' for i in range(1,21)]
col3=['r','w','b','brown']
col4=['k'if i%2==0 else 'w' for i in range(1,11)]
inside=np.ones(10)
lab2=np.ones(20)
lab=np.ones(20)
plt.pie([1],colors='k',radius=2.05)
plt.pie(lab,colors=col,radius=2.0)
plt.pie([1],colors='k',radius=1.1)
plt.pie([1],colors='g',radius=1.5)
plt.pie(lab2,colors=col2,radius=1.07)
plt.pie([1],colors='m',radius=0.7)
plt.pie(inside,colors=col4,radius=0.3)
plt.pie([1,1,1,1],colors=col3,radius=0.1)
# plt.title('pie chart with in a pie chart',loc='right')
# plt.savefig()
plt.show()

# %%
#,,,,,,,,,,all matplotlib functions show tricks,,,,,,,,,

matplotlib_functin_list=dir(plt)
matplotlib_functin_list[0:10]
# Out:
# ['Annotation',
#  'Arrow',
#  'Artist',
#  'AutoLocator',
#  'Axes',
#  'Button',
#  'Circle',
#  'Figure',
#  'FigureCanvasBase',
#  'FixedFormatter']

# %% [markdown]
# # savefigure function
# <p> this function is used for when will you want to save the figure,<br>
#     you can use the <b>savefigure function</b> and in this function you can <br>
#     putt the multiple parameter. like facecolor,path or filename,dpi,format,,,etc..</p>

# %%
plt.figure(figsize=(9,6))
col=['r'if i%2==0 else 'w' for i in range(1,21)]
col2=['w'if i%2==0 else 'b' for i in range(1,21)]
col3=['r','w','b','brown']
col4=['k'if i%2==0 else 'w' for i in range(1,11)]
inside=np.ones(10)
lab2=np.ones(20)
lab=np.ones(20)
plt.pie([1],colors='k',radius=2.05)
plt.pie(lab,colors=col,radius=2.0)
plt.pie([1],colors='k',radius=1.1)
plt.pie([1],colors='g',radius=1.5)
plt.pie(lab2,colors=col2,radius=1.07)
plt.pie([1],colors='m',radius=0.7)
plt.pie(inside,colors=col4,radius=0.3)
plt.pie([1,1,1,1],colors=col3,radius=0.1)
plt.savefig("pie_chart",facecolor='c')      # you  can use multiple parameter here
plt.show()

# %% [markdown]
# # Box plot

# %%
data=np.array(np.arange(1,121))
data[119]=450
data

# %%
plt.boxplot(data)
plt.grid(axis='y')
plt.show()
# HERE I DIFINED A OUTLIER

# percentage of boxplot will specify data point position

# %%
dataa=np.array(np.arange(1,120))
plt.boxplot(dataa)
# plt.show()
plt.grid(axis='y')

# as you can see 50 % ===  60 
# as you can see 25 % ===  30 
# as you can see 75 % ===  90 
# as you can see 100 % ===  120

# %%
# according to my chart prooved red line is represent the average value of my data as well as element position of 50%
data.sum()/120
# Out:
# 60.5

# %% [markdown]
# # stackplot
# <p>stackplot is also called area plot this plot is very interesting <br>
#     and more helpfull for know the about data distubution and <br>
#     and in this chart you can also draw the multiple area in a single plot</p>

# %%
plt.figure(figsize=(9,6))
style.use('seaborn-dark')
plt.subplot(3,1,1)
plt.stackplot(minute,player1,color='r',labels='player1')
plt.legend(loc='upper left')
plt.grid(axis='y',color='k')
# plt.title('player_1')
plt.subplot(3,1,2)
plt.stackplot(minute,player2,labels='player2')
plt.legend(loc='upper left')

# plt.title('player_2')
plt.subplot(3,1,3)
plt.stackplot(minute,player3,color='g',labels='player3')
plt.legend(loc='upper left')
# plt.title('player_3')
plt.show()

# %% [markdown]
# # and now we will draw the stackplot of tha above mentione three chart in a sinlge stackplot
# <p> then you can look a interesting fact of data</p>
# <B>NESTED STACKPLOT </B>

# %%
style.use('classic')
plt.figure(figsize=(8,7))
minute=[i for i in range(1,10)]
player1=[1, 2, 2, 2, 3, 4, 5, 5, 5]
player2=[2, 4, 4, 5, 5, 5, 7, 8, 8]
player3=[1,4,7,5,4,1,2,4,5]
labl=['player1','player2','player3']
plt.stackplot(minute,player1,player2,player3,labels=labl)
plt.legend(loc='upper left')
plt.title('stackplot')
plt.xlabel('minutes',fontsize=15)
plt.ylabel('players values',fontsize=15,color='b',family='serief')
plt.grid(color='k',linewidth=1,linestyle='solid')
plt.show()
print('here y axis is representing the total score of players by index or you can say ')
print('there are all three player are ziped and total value representing a stackplot')
# Out:
# here y axis is representing the total score of players by index or you can say
# there are all three player are ziped and total value representing a stackplot

# %% [markdown]
# # and now i will prove this chart minute 9
# <p> i am proving this , 9 minute what represnts</p>

# %%
# ,,,,,acording to my output minute 9 representing a total score of all players,,,,,,,,,,
a=player1[-1]
b=player2[-1]
c=player3[-1]
a+b+c
# Out:
# 18

# %% [markdown]
# # finally i made all that chart which are using in data science
# <p> and other charts we will learn in seaborn <br>
#     because seaborn is advance level of matplotlib</p>

# %% [markdown]
# <h1> 🌹Thank you !!!🌹</h1>

# %% [markdown]
# # precticle on a real dataset

# %%
df=pd.read_csv('battles.csv')

# %%
df.head()
# Out:
#                             name  year  battle_number  \
# 0     Battle of the Golden Tooth   298              1
# 1    Battle at the Mummer's Ford   298              2
# 2             Battle of Riverrun   298              3
# 3       Battle of the Green Fork   298              4
# 4  Battle of the Whispering Wood   298              5
#
#               attacker_king             defender_king attacker_1 attacker_2  \
# 0  Joffrey/Tommen Baratheon                Robb Stark  Lannister        NaN
# 1  Joffrey/Tommen Baratheon                Robb Stark  Lannister        NaN
# 2  Joffrey/Tommen Baratheon                Robb Stark  Lannister        NaN
# 3                Robb Stark  Joffrey/Tommen Baratheon      Stark        NaN
# 4                Robb Stark  Joffrey/Tommen Baratheon      Stark      Tully
#
#   attacker_3 attacker_4 defender_1  ... major_death  major_capture  \
# 0        NaN        NaN      Tully  ...         1.0            0.0
# ...

# %%
numeric=df.select_dtypes(exclude='O')
numeric.head()
# Out:
#    year  battle_number  defender_3  defender_4  major_death  major_capture  \
# 0   298              1         NaN         NaN          1.0            0.0
# 1   298              2         NaN         NaN          1.0            0.0
# 2   298              3         NaN         NaN          0.0            1.0
# 3   298              4         NaN         NaN          1.0            1.0
# 4   298              5         NaN         NaN          1.0            1.0
#
#    attacker_size  defender_size  summer
# 0        15000.0         4000.0     1.0
# 1            NaN          120.0     1.0
# 2        15000.0        10000.0     1.0
# 3        18000.0        20000.0     1.0
# 4         1875.0         6000.0     1.0

# %%
categorical=df.select_dtypes(include='O')
categorical.head()
# Out:
#                             name             attacker_king  \
# 0     Battle of the Golden Tooth  Joffrey/Tommen Baratheon
# 1    Battle at the Mummer's Ford  Joffrey/Tommen Baratheon
# 2             Battle of Riverrun  Joffrey/Tommen Baratheon
# 3       Battle of the Green Fork                Robb Stark
# 4  Battle of the Whispering Wood                Robb Stark
#
#               defender_king attacker_1 attacker_2 attacker_3 attacker_4  \
# 0                Robb Stark  Lannister        NaN        NaN        NaN
# 1                Robb Stark  Lannister        NaN        NaN        NaN
# 2                Robb Stark  Lannister        NaN        NaN        NaN
# 3  Joffrey/Tommen Baratheon      Stark        NaN        NaN        NaN
# 4  Joffrey/Tommen Baratheon      Stark      Tully        NaN        NaN
#
#   defender_1 defender_2 attacker_outcome     battle_type  \
# 0      Tully        NaN              win  pitched battle
# 1  Baratheon        NaN              win          ambush
# ...

# %%
numeric.isnull().sum()
# Out:
# year              0
# battle_number     0
# defender_3       38
# defender_4       38
# major_death       1
# major_capture     1
# attacker_size    14
# defender_size    19
# summer            1
# dtype: int64

# %%
plt.scatter(numeric['battle_number'],numeric['defender_size'])

# %%
grouped=df.groupby(['attacker_king'])

# %%
grouped['defender_size'].sum()
# Out:
# attacker_king
# Balon/Euron Greyjoy             0.0
# Joffrey/Tommen Baratheon    35820.0
# Robb Stark                  49625.0
# Stannis Baratheon           36690.0
# Name: defender_size, dtype: float64

# %%
df[df['attacker_king']=='Balon/Euron Greyjoy']['defender_size'].sum()

# baloon has no defender size
# Out:
# 0.0

# %%
attacker_king=list(grouped['defender_size'].sum().index)
attacker_king=attacker_king[1:]
attacker_king
# and now i will remove the baloon because it has no defence
# Out:
# ['Joffrey/Tommen Baratheon', 'Robb Stark', 'Stannis Baratheon']

# %%
defence_of_king=list(grouped['defender_size'].sum().values)
defence_of_king=defence_of_king[1:]
defence_of_king
# Out:
# [35820.0, 49625.0, 36690.0]

# %%
plt.figure(figsize=(8,10))
explod=[0.2,0,0]
plt.pie(defence_of_king,labels=attacker_king,wedgeprops={'edgecolor':'k',},autopct="%1.2f",explode=explod,shadow=True)   
plt.legend()
plt.title('defender size of attacker king',color='k',size=22)
# there label == labels
# Out:
# Text(0.5, 1.0, 'defender size of attacker king')

# %%
numeric[['attacker_size','defender_size']]
# now i will chek the relationship in between
# Out:
#     attacker_size  defender_size
# 0         15000.0         4000.0
# 1             NaN          120.0
# 2         15000.0        10000.0
# 3         18000.0        20000.0
# 4          1875.0         6000.0
# 5          6000.0        12625.0
# 6             NaN            NaN
# 7             NaN            NaN
# 8          1000.0            NaN
# 9           264.0            NaN
# 10          244.0          900.0
# 11           20.0            NaN
# 12            NaN            NaN
# 13          618.0         2000.0
# 14         6000.0        10000.0
# 15         5000.0        20000.0
# 16        20000.0        10000.0
# 17          100.0          100.0
# 18         6000.0            NaN
# 19        21000.0         7250.0
# 20            NaN            NaN
# 21         3000.0            NaN
# 22            NaN            NaN
# 23            NaN         6000.0
# 24            NaN            NaN
# 25         3500.0         3500.0
# 26            NaN            NaN
# ...

# %%
plt.figure(figsize=(9,7))
plt.scatter(df['attacker_size'],df['defender_size'],cmap=plt.cm.Accent_r)
plt.colorbar()
plt.xlabel('attacke_size')
plt.ylabel('defender_size')
# Out:
# Text(0, 0.5, 'defender_size')

# %% [markdown]
# ## and now i will chek further detail of this maximum attacker size

# %%
df[df['attacker_size']==df['attacker_size'].max()]
# Out:
#                       name  year  battle_number      attacker_king  \
# 27  Battle of Castle Black   300             28  Stannis Baratheon
#
#    defender_king attacker_1 attacker_2 attacker_3 attacker_4     defender_1  \
# 27  Mance Rayder  Free folk     Thenns     Giants        NaN  Night's Watch
#
#     ... major_death  major_capture  attacker_size defender_size  \
# 27  ...         1.0            1.0       100000.0        1240.0
#
#                                    attacker_commander  \
# 27  Mance Rayder, Tormund Giantsbane, Harma Dogshe...
#
#                                    defender_commander  summer      location  \
# 27  Stannis Baratheon, Jon Snow, Donal Noye, Cotte...     0.0  Castle Black
#
#              region note
# 27  Beyond the Wall  NaN
#
# [1 rows x 25 columns]

# %%
df[df['attacker_king']=='Balon/Euron Greyjoy']['attacker_size'].sum()
# Out:
# 1284.0

# %%
attacker_king2=list(df[['attacker_king','attacker_size']]['attacker_king'].value_counts().index)
attacker_king2
# Out:
# ['Joffrey/Tommen Baratheon',
#  'Robb Stark',
#  'Balon/Euron Greyjoy',
#  'Stannis Baratheon']

# %%
grouped['attacker_size'].sum().values
# Out:
# array([  1284.,  60618.,  41219., 135500.])

# %%
plt.figure(figsize=(8,7))
color=['r','y','b','k']
plt.bar(attacker_king2,grouped['attacker_size'].sum().values,color=color,edgecolor='g',lw=3)
plt.ylabel('attacker_size')
plt.xlabel('attacker_king')
# Out:
# Text(0.5, 0, 'attacker_king')
