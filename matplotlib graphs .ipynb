# %% [markdown]
# ## welcome to you in matplotlib
# ### int this notebook. i will try to cover all
# ### matplotlib

# %%
print('u can use this method for importing matplot pyplot')
# import matplotlib.pyplot
# import matplotlib.pyplot as plt
from matplotlib import pyplot as plt
# Out:
# u can use this method for importing matplot pyplot

# %%
lis=[method_name for method_name in dir(plt.plot)]
lis
#chek for how many function belong from plot
# Out:
# ['__annotations__',
#  '__call__',
#  '__class__',
#  '__closure__',
#  '__code__',
#  '__defaults__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__get__',
#  '__getattribute__',
#  '__globals__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__kwdefaults__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__name__',
#  '__ne__',
#  '__new__',
#  '__qualname__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__']

# %% [markdown]
# ## plot

# %%
plt.plot([1, 2, 3,8])
# plt.legend(["showline"])

# %%
plt.plot([1, 2, 3,8],'g',linewidth=5,label=["showline"])
plt.legend()
# plt.legend(["showline"]) you can use this type

# %% [markdown]
# ### if you passed single value than this chart represent the value by axis y

# %%
plt.plot([5, 1, 3,20],linewidth=5,label='single_line',color='r')
plt.legend()

# %%
plot1=plt.plot([1,2,3],[4,5,1])
plt.title("my first plot")
plt.xlabel("X_Axis")
plt.ylabel('Y_Axis')
# plt.show() #here this command is optional 
# without using this command my graph is displaying
# Out:
# Text(0, 0.5, 'Y_Axis')

# %% [markdown]
# ## fontdict parameter used for change the xlabel and ylable or tittle color and  size and font convert

# %%
style.use('seaborn-dark')
font1 = {'family':'serif','color':'blue','size':20}      # first we defined the dictionary
font2 = {'family':'serif','color':'black','size':15}
plot1=plt.plot([1,2,3],[4,3,1],'p:k',ms=15,label='fontsetting')   # and by using fontdict parameter use the property of dictionary
plt.xlabel('x-axis',fontdict=font2)
plt.ylabel("y-axis",fontdict=font1)
plt.title("text-formatting",loc='left',fontdict=font1)
plt.legend()
print()
print('in this cell we will cover all all that property which are used for text formatting')

# %% [markdown]
# # plot bar is suitable for single columns atribute and a sorted
# maner because it tells a basic progress of value

# %%
y=[2,5,8,6]

plt.plot(sorted(y),linestyle='dashed',linewidth=5)   # u can use here dotted dashed

# %%
x=[2,4,7,5,11,14,18]
plt.plot(x,marker='o')

# %%
x=[2,4,7,5,11,14,18]
plt.plot(x,marker='*',ms=17,mfc="r")     # mec='r' can used for set otline border of marker

# %%
x=[2,4,7,5,11,14,18]
plt.plot(x,marker='D')

# %%
x=[2,4,7,5,11,14,18]
plt.plot(x,marker='v')

# %% [markdown]
# ## here instead of line we will printing the point value
# # and (1,4),(5,6),(9,8) it means combinations of both axis

# %%
####   this is for more helpfull

x=[1,5,9]
y=[4,6,8]
# 'p:r' is fmt here p is star rectangle defines and : defines dotted line r defines the color
plt.plot(x,y,'p--r',ms=12,mfc='b')  # here p is used for the rectangle shape and r is used for line color

# %% [markdown]
# # -- is used for dashed line and ms parameter is used for marker size difine

# %%
x=[1,5,9]
y=[4,6,8]
plt.plot(x,y,'o--r',color='k',ms=15)

# %%
x=[5,8,10]
y=[12,16,6]
x2=[6,9,11]
y2=[6,15,7]

# %% [markdown]
# ## two plot line create simultaneously

# %%
style.use('seaborn-dark')
plt.plot(x,y,'g',label='first line',linewidth=3)
plt.plot(x2,y2,'red',label='second line',linewidth=5)
plt.title("two lines on a single chart")
plt.xlabel("X_AXIS")
plt.ylabel("Y_AXIS")
plt.legend()                      # for labels onthe right corners 
plt.grid(True)     #for gridlines  u can draw only single axis gridlines or y axis gridlines
#colors shortcuts keys
#c:- for purple
#g:- for green
#k:- for black

# %% [markdown]
# ### Here i am adding some future like main label,x axis label and y axis labe

# %% [markdown]
# ## and now i am adding another some feature of plot in this graph

# %%
# style module in matplotli
from matplotlib import style           # style func. is used to design our graph and we can add some anothr property of design

# %% [markdown]
# ## these are all styles of style module in matplotlib

# %%
for styles in plt.style.available:
    print(styles)
print()
print('these are all style in styl module we can use separately all these styles but next time')
# Out:
# Solarize_Light2
# _classic_test_patch
# bmh
# classic
# dark_background
# fast
# fivethirtyeight
# ggplot
# grayscale
# seaborn
# seaborn-bright
# seaborn-colorblind
# seaborn-dark
# seaborn-dark-palette
# seaborn-darkgrid
# seaborn-deep
# seaborn-muted
# seaborn-notebook
# seaborn-paper
# seaborn-pastel
# seaborn-poster
# seaborn-talk
# seaborn-ticks
# seaborn-white
# seaborn-whitegrid
# tableau-colorblind10
#
# these are all style in styl module we can use separately all these styles but next time

# %%
style.use('classic')       #we are using plot on this ggplot

# %%
dir(plt.style) # this is used for how many function available inside the topic
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  'available',
#  'context',
#  'core',
#  'library',
#  'reload_library',
#  'use']

# %%
[method_name for method_name in dir(style.use)]
# i don,nt know what is this but in future i will try that what is this containt
# Out:
# ['__annotations__',
#  '__call__',
#  '__class__',
#  '__closure__',
#  '__code__',
#  '__defaults__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__get__',
#  '__getattribute__',
#  '__globals__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__kwdefaults__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__name__',
#  '__ne__',
#  '__new__',
#  '__qualname__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__']

# %%
print(len(dir(plt)))
dir(plt)
#these are all functionalty of pyplot
# Out:
# 250
# ['Annotation',
#  'Arrow',
#  'Artist',
#  'AutoLocator',
#  'Axes',
#  'Button',
#  'Circle',
#  'Figure',
#  'FigureCanvasBase',
#  'FixedFormatter',
#  'FixedLocator',
#  'FormatStrFormatter',
#  'Formatter',
#  'FuncFormatter',
#  'GridSpec',
#  'IndexLocator',
#  'Line2D',
#  'LinearLocator',
#  'Locator',
#  'LogFormatter',
#  'LogFormatterExponent',
#  'LogFormatterMathtext',
#  'LogLocator',
#  'MaxNLocator',
#  'MouseButton',
#  'MultipleLocator',
#  'Normalize',
#  'NullFormatter',
#  'NullLocator',
#  'Number',
#  'PolarAxes',
#  'Polygon',
#  'Rectangle',
#  'ScalarFormatter',
#  'Slider',
#  'Subplot',
#  'SubplotTool',
#  'Text',
#  'TickHelper',
#  'Widget',
#  '_INSTALL_FIG_OBSERVER',
#  '_IP_REGISTERED',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_auto_draw_if_interactive',
#  '_backend_mod',
#  '_code_objs',
#  '_copy_docstring_and_deprecators',
# ...

# %% [markdown]
# ## alpha is used for opacity of the point ,range of alpha 0 to 1
#  you can use here alpha parameter and not too.
#  you can not see difference there without using alpha
#  by default point color is blue but u can use color parameter here
# # whenever we wil use the scatter , while we have two numerical columns and we want to merge the result with axis x,and axis y
# ## a single point represent a two columns value with the help of x axis and y axis

# %%
plt.scatter(x2,y2,color='r',alpha=0.9,label=['show label'])
plt.legend()
plt.xlabel('x2')
plt.ylabel('y2')
print('x and y value',x2,y2)
# Out:
# x and y value [6, 9, 11] [6, 15, 7]

# %% [markdown]
# # bar plot
# when we will use the bar plot whenever we want to see whose chategoery fastes grow
# and for checkout where is the highest value
# you can use here x columns --> categorical columns
# and y axis --> numerical columns

# %%
plt.bar([1,3,5,7,8],[5,8,7,4,8])   #here must be equal both list size  
# and here u con,t single axis 
# [x_axis,y_axis]
plt.title('bar plot')
# Out:
# Text(0.5, 1.0, 'bar plot')

# %% [markdown]
# ## here i am using same name mohan two times
# and you can see now where mohan has greatest value than bar will be increase like that

# %%
plt.bar(["mohan",'raju','mohan','kiran','shyam'],[5,2,7,8,2],label='customers',color='g')
plt.ylabel("profit")
plt.xlabel("sell")
plt.title("bar plot")
# plt.grid(True)
plt.legend()        #without using legend function u can,t display the

# %% [markdown]
# ## two bar create simultaneously

# %%
plt.bar([1,3,5,7,9],[5,2,7,8,2],label='first bar',color='k')
plt.bar([8,4,6],[5,9,2],label='second bar',color='g')
#here if you passed same xaxis any for the both bar
# you should keep remeber that it is not possible
# t
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
# ## bar plot is representation of catogorical data

# %%
# here i am creating bar plot for database
x=["maharashtra",'tamilnade','chenni','lucknow',]
y=[825,555,342,223]
plt.bar(x,y,color='dodgerblue',label='database bar plot')
plt.legend()
plt.title("data base chart")
plt.ylabel("cases")
plt.xlabel("area")
# Out:
# Text(0.5, 0, 'area')

# %% [markdown]
# # histogram for the datadistribution
# this is one of best chart according to me for the data distribution ,<br>
# here we will create a bins in this we will the list according to my bar will be create
# and with filling the our density range
# ## and always remeber bins is axis x value
# but sytex assigning some deffirent (x,y) instead of (population,bins)

# %%
# and bins size aways in ascending sorted maner
bins=[0,20,40,60,80,100]       #bins size is 11 but here only 10 bar will be created
population_ages=[22,55,62,54,85,45,25,14,65,74,54,65,25,1,2,10,25,45,85,47,56,95,5,69,36,46,52,74,76,48,49,85,59,51,52,48,75,69,57,58,97,98,32,25,18,17,19,21,22,23,24,26,21,35,34]
plt.hist(population_ages,bins,histtype='bar',rwidth=0.8)
plt.xlabel('population record')
plt.ylabel('the value of population according to my bins')
plt.title('histogram')
# Out:
# Text(0.5, 1.0, 'histogram')

# %%
bins=[0,17,25,35,50,70,100]  #binsize always incremental
population_ages=[22,55,62,54,85,45,25,14,65,74,54,65,25,1,2,10,25,45,85,47,56,95,5,69,36,46,52,74,76,48,49,85,59,51,52,48,75,69,57,58,97,98,32,25,18,17,19,21,22,23,24,26,21,35,34]
plt.hist(population_ages,bins,histtype='bar',rwidth=0.8)
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.title('histogram')
# Out:
# Text(0.5, 1.0, 'histogram')

# %% [markdown]
# ## here i was used the python for some additional help

# %%
new_list=[]
for i in population_ages:
    
    if i>60 and i<80:
        new_list.append(i)
print(new_list)
# Out:
# [62, 65, 74, 65, 69, 74, 76, 75, 69]

# %%
list_of_elemnt_whichare_abovesixteen=[i for i in population_ages if i>60 and i<80]
print(min(list_of_elemnt_whichare_abovesixteen))
print(len(list_of_elemnt_whichare_abovesixteen))
print(max(list_of_elemnt_whichare_abovesixteen))
print(sum(list_of_elemnt_whichare_abovesixteen))
list_of_elemnt_whichare_abovesixteen
# Out:
# 62
# 9
# 76
# 629
# [62, 65, 74, 65, 69, 74, 76, 75, 69]

# %% [markdown]
# ## scatteer plot
# ### is used to campare two value x and y

# %%
profit=[20,12,32,43,21,32,3,43,51,23,32,43,43]
# sells=[33,22,44,11,21,12,13,15,34,23,64,66,44]
sell
plt.hist(profit,sell,label='pytho',color='red')
plt.xlabel('sells')
plt.ylabel('profit')
plt.title('scatter plot')
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-63-eeb2aee18b27> in <module>
#       1 profit=[20,12,32,43,21,32,3,43,51,23,32,43,43]
#       2 # sells=[33,22,44,11,21,12,13,15,34,23,64,66,44]
# ----> 3 sell
#       4 plt.hist(profit,sell,label='pytho',color='red')
#       5 plt.xlabel('sells')
#
# NameError: name 'sell' is not defined

# %%
population_ages=[22,55,62,54,85,45,25,14,65,74,54,65,25,1,2,10,25,45,85,47,56,95,5,69,36,46,52,74,76,48,49,85,59,51,52,48,75,69,57,58,97,98,32,25,18,17,19,21,22,23,24,26,21,35,34]
categoery=[0,20,40,60,80,100,120]
plt.hist(population_ages,categoery,color='orange',histtype='bar',label='chart',rwidth=0.8)
plt.title('histogram')
plt.ylabel('population_ages')
plt.xlabel('catigory wise segmentation')
plt.legend()
# plt.grid(True,color='k')   #for gridline

# %%
sells=[33,22,44,11,21,12,13,15,34,23,64,66,44]
sell=sorted(sells)

# %%
len(sell)
# Out:
# 13

# %%
sells=[33,22,44,11,21,12,13,15,34,23,64,66,44]
sell=sorted(sells)
profit=[20,12,32,43,21,32,3,43,51,23,32,43,43]
# sells=[33,22,44,11,21,12,13,15,34,23,64,66,44]
# sell=[11, 12, 13, 15, 21, 22, 23, 33, 34, 44, 44, 64, 66]
plt.hist(profit,sell,label='pytho',histtype='bar',color='red')
plt.xlabel('sells')
plt.ylabel('profit')
plt.title('histogram')
plt.legend()
