# %%
import pandas as pd

# %%
df=pd.read_csv('IRIS.csv')
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
df.query("species=='Iris-setosa' ")
# Out:
#     sepal_length  sepal_width  petal_length  petal_width      species
# 0            5.1          3.5           1.4          0.2  Iris-setosa
# 1            4.9          3.0           1.4          0.2  Iris-setosa
# 2            4.7          3.2           1.3          0.2  Iris-setosa
# 3            4.6          3.1           1.5          0.2  Iris-setosa
# 4            5.0          3.6           1.4          0.2  Iris-setosa
# 5            5.4          3.9           1.7          0.4  Iris-setosa
# 6            4.6          3.4           1.4          0.3  Iris-setosa
# 7            5.0          3.4           1.5          0.2  Iris-setosa
# 8            4.4          2.9           1.4          0.2  Iris-setosa
# 9            4.9          3.1           1.5          0.1  Iris-setosa
# 10           5.4          3.7           1.5          0.2  Iris-setosa
# 11           4.8          3.4           1.6          0.2  Iris-setosa
# ...

# %%
df.query("sepal_length < 5 ")
# Out:
#      sepal_length  sepal_width  petal_length  petal_width          species
# 1             4.9          3.0           1.4          0.2      Iris-setosa
# 2             4.7          3.2           1.3          0.2      Iris-setosa
# 3             4.6          3.1           1.5          0.2      Iris-setosa
# 6             4.6          3.4           1.4          0.3      Iris-setosa
# 8             4.4          2.9           1.4          0.2      Iris-setosa
# 9             4.9          3.1           1.5          0.1      Iris-setosa
# 11            4.8          3.4           1.6          0.2      Iris-setosa
# 12            4.8          3.0           1.4          0.1      Iris-setosa
# 13            4.3          3.0           1.1          0.1      Iris-setosa
# 22            4.6          3.6           1.0          0.2      Iris-setosa
# 24            4.8          3.4           1.9          0.2      Iris-setosa
# ...

# %%
df.query("species=='Iris-setosa' ").plot(kind='bar',figsize=(15,20))
# Out:
# <AxesSubplot:>

# %%
df.query("sepal_length < 5 ").plot(kind='bar',figsize=(10,8))
# Out:
# <AxesSubplot:>

# %%
df.query("sepal_length < 5 ").plot(x='sepal_length',y='petal_length',kind='scatter',figsize=(7,8),color='r',marker='*')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
df.query("sepal_length < 5 ").plot(y='sepal_length',kind='pie',figsize=(8,10))
# Out:
# <AxesSubplot:ylabel='sepal_length'>

# %%
df.query("sepal_length < 5 ")['sepal_length'].index
# Out:
# Int64Index([  1,   2,   3,   6,   8,   9,  11,  12,  13,  22,  24,  29,  30,
#              34,  37,  38,  41,  42,  45,  47,  57, 106],
#            dtype='int64')

# %%
df.query("sepal_length < 5 ").plot(y='petal_width',kind='pie',figsize=(8,10),shadow=True)
# Out:
# <AxesSubplot:ylabel='petal_width'>

# %%
df.plot(kind='box',color='r')
# Out:
# <AxesSubplot:>

# %%
df.plot(x='sepal_length',y='petal_length',kind='hexbin',alpha=1)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>
