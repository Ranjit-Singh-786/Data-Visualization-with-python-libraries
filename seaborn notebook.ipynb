# %% [markdown]
# # Welcome to you in my Seaborn notebook !😎

# %% [markdown]
# <b>1. Numerical data ploting</b>
# <ul>
#     <li>relplot()</li>
#     <li>scatterplot()</li>
#     <li>lineplot()</li>
#     </ul>
#     <b>2. categorical data ploting</b>
#     <ul>
#         <li>catplot()</li>
#         <li>boxplot()</li>
#         <li>stripplot()</li>
#         <li>swarmplot()</li>
#     </ul>
#     <b>3. visualizing distribution of the data</b>
#     <ul>
#         <li>displot()</li>
#         <li>boxplot()</li>
#         <li>Kdeplot()</li>
#         <li>joinplot()</li>
#     <li>rugplot()</li>
#     </ul>
#     <b>4. linear Regression and relationship</b>
#     <ul>
#         <li>regplot()</li>
#         <li>implot()</li>
# </ul>
# <b>5.controlling ploted figure aesthetics </b>
#     <ul>
#         <li>figure styling</li>
#         <li>axes styling</li>
#         <li>color palettes</li>
#     </ul

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import  matplotlib.style as slt

# %%
# %matplotlib inline

# %% [markdown]
# # direct data import from the seaborn repository on the github

# %%
data =sns.load_dataset('tips')
data.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3

# %%
sns.set(style='darkgrid')   # for t

# %%
dir(sns.FacetGrid)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_bottom_axes',
#  '_clean_axis',
#  '_facet_color',
#  '_facet_plot',
#  '_finalize_grid',
#  '_get_palette',
#  '_inner_axes',
#  '_left_axes',
#  '_legend_out',
#  '_margin_titles',
#  '_not_bottom_axes',
#  '_not_left_axes',
#  '_update_legend_data',
#  'add_legend',
#  'ax',
#  'axes',
#  'axes_dict',
#  'despine',
#  'facet_axis',
#  'facet_data',
#  'fig',
#  'legend',
#  'map',
#  'map_dataframe',
#  'savefig',
#  'set',
#  'set_axis_labels',
#  'set_titles',
#  'set_xlabels',
#  'set_xticklabels',
#  'set_ylabels',
#  'set_yticklabels',
#  'tight_layout']

# %% [markdown]
# # relplot
# <p>remebered that you can also use pyplot property here</p>

# %%
sns.relplot(x='total_bill',y='tip',data=data,hue='smoker')

# %% [markdown]
# # col parameter

# %%
sns.relplot(x='total_bill',y='tip',data=data,hue='smoker',row='time')

# %%
sns.relplot(x='total_bill',y='tip',data=data,hue='smoker',col='time')
plt.grid(axis='y')
# hue parameter change the color according to category of a columns

# %% [markdown]
# # style parameter in relplot()

# %%
sns.relplot(x='total_bill',y='tip',data=data,hue='smoker',style='time')
# these plot is very helpfull for the particular point
print('and now i will seprate lunch and dinner records in the scatterplot ')
print('by using col parameter')
# Out:
# and now i will seprate lunch and dinner records in the scatterplot
# by using col parameter

# %%
sns.relplot(x='total_bill',y='tip',hue='smoker',style='time',col='time',data=data)
print('u can see here now lunch and dinner point has seprated in two columns')
# Out:
# u can see here now lunch and dinner point has seprated in two columns

# %%
sns.relplot(x='total_bill',y='tip',hue='size',data=data,style='time')

print('here available category in the size columns is bigger size')
print('so color combination divided in to maximum color and separete color represent a ')
print('separete catogory')
# Out:
# here available category in the size columns is bigger size
# so color combination divided in to maximum color and separete color represent a
# separete catogory

# %%
print('size columns category')
print(data['size'].value_counts())
print()
print('time column category present her')
print()
print(data['time'].value_counts())
# Out:
# size columns category
# 2    156
# 3     38
# 4     37
# 5      5
# 1      4
# 6      4
# Name: size, dtype: int64
#
# time column category present her
#
# Dinner    176
# Lunch      68
# Name: time, dtype: int64

# %% [markdown]
# # for change the color palette parameter

# %%
# data['size'].value_counts()
col=['r','g','c','y','k','b']

# %%
sns.relplot(x='total_bill',y='tip',hue='size',data=data,palette=col)    # 'ch:r=0.8,l=0.70'   u can also use this method in palette 
# you can customize the color value here

# %%
sns.relplot(x='total_bill',y='tip',hue='time',data=data,style='size',palette=['g','brown'])
print('remebered if you have multiple category then ')
print('style will be convert multile and assign the separate')
print('style for the unique category')
# Out:
# remebered if you have multiple category then
# style will be convert multile and assign the separate
# style for the unique category

# %% [markdown]
# # color parameter for chang the single color in proper points

# %%
sns.relplot(x='total_bill',y='tip',color='r',data=data)

# %% [markdown]
# # for change the size with size parameter

# %%
sns.relplot(x='tip',y='total_bill',data=data,size='size')
plt.show()
print('here you can see now size are changing according to ')
print(' my size value ')
# Out:
# here you can see now size are changing according to
#  my size value

# %% [markdown]
# # for change defualt size of size parameter with the help of sizes parameter

# %%
sns.relplot(x='total_bill',y='tip',data=data,size='size')
print('this is defualt size but  we will customized the defualt size')
# Out:
# this is defualt size but  we will customized the defualt size

# %%
sns.relplot(x='total_bill',y='tip',color=['r'],data=data,size='size',sizes=(100,500))
print('this size is changin in between the 100 to 500')
# Out:
# this size is changin in between the 100 to 500

# %% [markdown]
# # kind parameter for change the relplot property
# <p> this is by default scatter but if you want to change then you can change it

# %%
sns.relplot(x='total_bill',y='tip',data=data,kind='line',sort=True)        # by defualt sort parameter is true

# %%
df=pd.DataFrame(dict(number=np.arange(200),value=np.random.randn(200).cumsum()))

# %%
sns.relplot(x='number',y='value',color='r',kind='line',data=df)

# %%
df=pd.DataFrame(np.random.randn(500,2).cumsum(axis=0),columns=['time','values'])
df.head()
# Out:
#        time    values
# 0  0.238900 -1.515378
# 1 -0.003759 -0.099709
# 2  1.033585  0.484623
# 3  2.109697  2.397435
# 4  3.492427  3.132304

# %% [markdown]
# # understanding sort parameter
# by default sort parameter is true

# %%
sns.relplot(x='time',y='values',kind='line',data=df,height=4)

# %%
sns.relplot(x='time',y='values',kind='line',data=df,height=4,sort=False)
print('when i did sort false then you can see the result')
# Out:
# when i did sort false then you can see the result

# %%
fmri=sns.load_dataset('fmri')
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
fmri.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1064 entries, 0 to 1063
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   subject    1064 non-null   object
#  1   timepoint  1064 non-null   int64
#  2   event      1064 non-null   object
#  3   region     1064 non-null   object
#  4   signal     1064 non-null   float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 41.7+ KB

# %%
sns.relplot(x='timepoint',y='signal',kind='line',data=fmri)
print('you can see here confident interval')
# Out:
# you can see here confident interval

# %% [markdown]
# # ci=False for removing the confident interval

# %%
sns.relplot(x='timepoint',y='signal',kind='line',data=fmri,ci=False)

# %% [markdown]
# # pass standard division in ci parameter

# %%
sns.relplot(x='timepoint',y='signal',kind='line',data=fmri,ci='sd')
print('it is returning a standard division chart with confident interval')
# Out:
# it is returning a standard division chart with confident interval

# %% [markdown]
# # here estimator used for create a chart with actual value

# %%
sns.relplot(x='timepoint',y='signal',estimator=None,kind='line',data=fmri)

# %% [markdown]
# # hue chart two lines bcz there are category

# %%
import matplotlib.style as slt
slt.use('ggplot')
sns.relplot(x='timepoint',y='signal',hue='event',kind='line',data=fmri)

# %%
sns.relplot(x='timepoint',y='signal',hue='region',style='event',kind='line',data=fmri)

# %% [markdown]
# # without confident interval but marker and  dashes parameter

# %%
sns.relplot(x='timepoint',y='signal',hue='region',style='event',kind='line',data=fmri,markers=True,ci=None,dashes=False)

# %% [markdown]
# # hue and style both apply on a single column

# %%
sns.relplot(x='timepoint',y='signal',kind='line',hue='event',style='event',data=fmri,markers=True,ci=None,palette=['g','b'])

# %%
data=pd.read_csv('IRIS.csv')
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
data.species.value_counts()
# Out:
# Iris-setosa        50
# Iris-virginica     50
# Iris-versicolor    50
# Name: species, dtype: int64

# %%
# int the matplotlib for the scatter plot we used to only scatter()function
# for show the relation in between two columns
# untill u will not define the data parameter you can not use the hue parameter
sns.scatterplot(data['sepal_length'],data['petal_length'],data=data,hue='species')
plt.show()

# %%
# you can use here pyplot property and style property 
slt.use('classic')
sns.set_theme(style='ticks')
sns.set(rc={'figure.figsize':(10,7)})
sns.scatterplot(data['sepal_width'],data['petal_width'],data=data,hue='species')
plt.legend(loc='upper right')
plt.title('Scatter plot with hue parameter',fontsize=15,color='k')

plt.show()
# Out:
# c:\users\dell\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
list_of_allfunction=dir(sns)
print(type(list_of_allfunction))
print('all function in the seaborn !')
list_of_allfunction
# Out:
# <class 'list'>
# all function in the seaborn !
# ['FacetGrid',
#  'JointGrid',
#  'PairGrid',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_core',
#  '_decorators',
#  '_docstrings',
#  '_orig_rc_params',
#  '_statistics',
#  'algorithms',
#  'axes_style',
#  'axisgrid',
#  'barplot',
#  'blend_palette',
#  'boxenplot',
#  'boxplot',
#  'categorical',
#  'catplot',
#  'choose_colorbrewer_palette',
#  'choose_cubehelix_palette',
#  'choose_dark_palette',
#  'choose_diverging_palette',
#  'choose_light_palette',
#  'clustermap',
#  'cm',
#  'color_palette',
#  'colors',
#  'countplot',
#  'crayon_palette',
#  'crayons',
#  'cubehelix_palette',
#  'dark_palette',
#  'desaturate',
#  'despine',
#  'displot',
#  'distplot',
#  'distributions',
#  'diverging_palette',
#  'dogplot',
#  'ecdfplot',
#  'external',
#  'factorplot',
#  'get_data_home',
# ...

# %%
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# # bar plot

# %%
slt.use('classic')
sns.set(rc={'figure.figsize':(10,7)})
sns.barplot(data['species'],data['sepal_length'])
plt.grid(axis='y',color='k',linestyle='dotted')
plt.show()
# Out:
# c:\users\dell\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.barplot(data['species'],data['petal_length'])
plt.show()
# Out:
# c:\users\dell\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
data[data['species']=='virginica'].max()
# Out:
# sepal_length          7.9
# sepal_width           3.8
# petal_length          6.9
# petal_width           2.5
# species         virginica
# dtype: object

# %% [markdown]
# # lineplot
# <p> you can use here all of the facility of matplotlib</p>
# <p> inthe seaborn without warrying order of the series. you can direct draw the chart<br>
#     seaborn is advance lenvel of matplotlib library.<br>
#     </p>

# %%
sns.set(rc={'figure.figsize':(7,4)})
sns.set_theme(style="ticks")                      #for the them set
slt.use('classic')
sns.lineplot(data['petal_length'],data['sepal_length'],marker='o',mfc='r')
plt.title('lineplot from the seaborn',fontsize=15,color='b')

plt.show()
# Out:
# c:\users\dell\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
data.max()
# Out:
# sepal_length          7.9
# sepal_width           4.4
# petal_length          6.9
# petal_width           2.5
# species         virginica
# dtype: object

# %% [markdown]
# # plot line plot from the matplotlib
# <p> you can see the difference between line plot from matplotlib and seaborn matplotlib</p>

# %%
plt.plot(data['petal_length'],data['sepal_length'])

# %% [markdown]
# # histplot from the seaborn

# %%
sns.set_theme(style='ticks')
# col=['r','g','y','b','c','hotpink','brown','dodgerblue','pink']
sns.histplot(data['sepal_length'])
plt.grid(axis='y',color='k',linestyle='solid')
plt.show()
print("you are watching this histplot chart ")
print()
print("and now i will prove this chart that is it true or not  ")
print('you can see below mentioned resullt there are only 6 entries ')
print('which are greater than 7.5')
# Out:
# you are watching this histplot chart
#
# and now i will prove this chart that is it true or not
# you can see below mentioned resullt there are only 6 entries
# which are greater than 7.5

# %%
data[data['sepal_length']>7.5].shape[0]
# Out:
# 6

# %%
# histplot with bin you can use property of the matplotlib

bin=[0,2,4,6,8]
sns.histplot(data['petal_length'],bins=bin)
# Out:
# <AxesSubplot:xlabel='petal_length', ylabel='Count'>

# %%
sns.histplot(data['petal_length'],linewidth=.8,palette="light:m_r",edgecolor=".1",)        #linewidth for the middlle space line in between bars
# Out:
# <AxesSubplot:xlabel='petal_length', ylabel='Count'>

# %% [markdown]
# # histplot with log_scaler=True

# %%
sns.histplot(data['petal_length'],linewidth=.8,palette="light:m_r",edgecolor=".1",log_scale=True)
# Out:
# <AxesSubplot:xlabel='petal_length', ylabel='Count'>

# %%
category=data['species'].value_counts()
category
# Out:
# setosa        50
# versicolor    50
# virginica     50
# Name: species, dtype: int64

# %%
name=category.index
name
# Out:
# Index(['setosa', 'versicolor', 'virginica'], dtype='object')

# %%
plt.figure(figsize=(10,8))
explode=[0,0,0.2]
plt.pie(category,labels=name,explode=explode,shadow=True,autopct='%1.2f%%',startangle=90)
plt.legend(loc='lower left')
plt.show()

# %%
grouped=data.groupby(data['species'])
grouped

# %%
grouped['sepal_length'].value_counts().loc['setosa']
# Out:
# sepal_length
# 5.0    8
# 5.1    8
# 4.8    5
# 5.4    5
# 4.6    4
# 4.9    4
# 4.4    3
# 5.2    3
# 4.7    2
# 5.5    2
# 5.7    2
# 4.3    1
# 4.5    1
# 5.3    1
# 5.8    1
# Name: sepal_length, dtype: int64

# %%
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
